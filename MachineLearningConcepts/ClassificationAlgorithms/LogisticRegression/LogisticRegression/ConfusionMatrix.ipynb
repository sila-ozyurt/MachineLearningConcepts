# %%
#CONFUSION MATRIX
#accuracy paradox

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("veriler.csv")
df=data.copy()
df
# Out:
#    ulke  boy  kilo  yas cinsiyet
# 0    tr  130    30   10        e
# 1    tr  125    36   11        e
# 2    tr  135    34   10        k
# 3    tr  133    30    9        k
# 4    tr  129    38   12        e
# 5    tr  180    90   30        e
# 6    tr  190    80   25        e
# 7    tr  175    90   35        e
# 8    tr  177    60   22        k
# 9    us  185   105   33        e
# 10   us  165    55   27        k
# 11   us  155    50   44        k
# 12   us  160    58   39        k
# 13   us  162    59   41        k
# 14   us  167    62   55        k
# 15   fr  174    70   47        e
# 16   fr  193    90   23        e
# 17   fr  187    80   27        e
# 18   fr  183    88   28        e
# 19   fr  159    40   29        k
# 20   fr  164    66   32        k
# 21   fr  166    56   42        k

# %%
#split data
x=df.iloc[:,[1,2,3]]
x
# Out:
#     boy  kilo  yas
# 0   130    30   10
# 1   125    36   11
# 2   135    34   10
# 3   133    30    9
# 4   129    38   12
# 5   180    90   30
# 6   190    80   25
# 7   175    90   35
# 8   177    60   22
# 9   185   105   33
# 10  165    55   27
# 11  155    50   44
# 12  160    58   39
# 13  162    59   41
# 14  167    62   55
# 15  174    70   47
# 16  193    90   23
# 17  187    80   27
# 18  183    88   28
# 19  159    40   29
# 20  164    66   32
# 21  166    56   42

# %%
y=df["cinsiyet"]
y
# Out:
# 0     e
# 1     e
# 2     k
# 3     k
# 4     e
# 5     e
# 6     e
# 7     e
# 8     k
# 9     e
# 10    k
# 11    k
# 12    k
# 13    k
# 14    k
# 15    e
# 16    e
# 17    e
# 18    e
# 19    k
# 20    k
# 21    k
# Name: cinsiyet, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

ss=StandardScaler()

x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
#logistic regression to predict cinsiyet column

from sklearn.linear_model import LogisticRegression

log_reg=LogisticRegression(random_state=0)

log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_predicted=log_reg.predict(x_test)
y_predicted
# Out:
# array(['e', 'e', 'e', 'e', 'k', 'e', 'e', 'e'], dtype=object)

# %%
y_test
# Out:
# 20    k
# 10    k
# 14    k
# 13    k
# 1     e
# 21    k
# 11    k
# 19    k
# Name: cinsiyet, dtype: object

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[0, 1],
#        [7, 0]], dtype=int64)

# %%
#first 4 lines are outliers so take them out and try again
df
# Out:
#    ulke  boy  kilo  yas cinsiyet
# 0    tr  130    30   10        e
# 1    tr  125    36   11        e
# 2    tr  135    34   10        k
# 3    tr  133    30    9        k
# 4    tr  129    38   12        e
# 5    tr  180    90   30        e
# 6    tr  190    80   25        e
# 7    tr  175    90   35        e
# 8    tr  177    60   22        k
# 9    us  185   105   33        e
# 10   us  165    55   27        k
# 11   us  155    50   44        k
# 12   us  160    58   39        k
# 13   us  162    59   41        k
# 14   us  167    62   55        k
# 15   fr  174    70   47        e
# 16   fr  193    90   23        e
# 17   fr  187    80   27        e
# 18   fr  183    88   28        e
# 19   fr  159    40   29        k
# 20   fr  164    66   32        k
# 21   fr  166    56   42        k

# %%
#split data
x=df.iloc[4:,[1,2,3]]
x
# Out:
#     boy  kilo  yas
# 4   129    38   12
# 5   180    90   30
# 6   190    80   25
# 7   175    90   35
# 8   177    60   22
# 9   185   105   33
# 10  165    55   27
# 11  155    50   44
# 12  160    58   39
# 13  162    59   41
# 14  167    62   55
# 15  174    70   47
# 16  193    90   23
# 17  187    80   27
# 18  183    88   28
# 19  159    40   29
# 20  164    66   32
# 21  166    56   42

# %%
y=df.iloc[4:,[4]]
y
# Out:
#    cinsiyet
# 4         e
# 5         e
# 6         e
# 7         e
# 8         k
# 9         e
# 10        k
# 11        k
# 12        k
# 13        k
# 14        k
# 15        e
# 16        e
# 17        e
# 18        e
# 19        k
# 20        k
# 21        k

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=0)

# %%
#scale them

x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
#logistic regression

log_reg.fit(x_train,y_train)

y_predicted=log_reg.predict(x_test)
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1229: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_predicted
# Out:
# array(['e', 'e', 'k', 'k', 'e', 'e'], dtype=object)

# %%
y_test
# Out:
#    cinsiyet
# 5         e
# 10        k
# 12        k
# 14        k
# 18        e
# 8         k

# %%
confusion_matrix(y_test,y_predicted)
# Out:
# array([[2, 0],
#        [2, 2]], dtype=int64)

# %%
"""
Accuracy: (TP + TN) / (TP + TN + FP + FN)
Sensitivity (True Positive Rate): TP / (TP + FN)
Specificity (True Negative Rate): TN / (TN + FP)
Specificity (True Negative Rate): TN / (TN + FP)
"""
# Out:
# '\nAccuracy: (TP + TN) / (TP + TN + FP + FN)\nSensitivity (True Positive Rate): TP / (TP + FN)\nSpecificity (True Negative Rate): TN / (TN + FP)\nSpecificity (True Negative Rate): TN / (TN + FP)\n'

# %%
"""

import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Veriyi ayırma
x = df.iloc[:, [1, 2]]  # İki özellik seçiyoruz
y = df["cinsiyet"]

# Eğitim ve test setlerine ayırma
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Ölçeklendirme
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Logistic Regression modelini eğitme
log_reg = LogisticRegression(random_state=0)
log_reg.fit(x_train_scaled, y_train)

# Tahmin yapma
y_pred = log_reg.predict(x_test_scaled)

# Confusion matrix oluşturma
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Metikleri hesaplama
TP = cm[1, 1]  # True Positives
TN = cm[0, 0]  # True Negatives
FP = cm[0, 1]  # False Positives
FN = cm[1, 0]  # False Negatives

# Doğruluk
accuracy = (TP + TN) / float(TP + TN + FP + FN)
print(f"Accuracy: {accuracy}")

# Hassasiyet (Recall)
sensitivity = TP / float(TP + FN)
print(f"Sensitivity (Recall): {sensitivity}")

# Özgüllük (Specificity)
specificity = TN / float(TN + FP)
print(f"Specificity: {specificity}")

# Kesinlik (Precision)
precision = TP / float(TP + FP)
print(f"Precision: {precision}")

# F1 Skor
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1}")

# Alternatif olarak scikit-learn metriklerini kullanarak hesaplayabilirsiniz:
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)  # recall = sensitivity
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall (Sensitivity): {recall}")
print(f"F1 Score: {f1}")

"""
# Out:
# '\n\nimport numpy as np\nfrom sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score\n\n# Veriyi ayırma\nx = df.iloc[:, [1, 2]]  # İki özellik seçiyoruz\ny = df["cinsiyet"]\n\n# Eğitim ve test setlerine ayırma\nx_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)\n\n# Ölçeklendirme\nscaler = StandardScaler()\nx_train_scaled = scaler.fit_transform(x_train)\nx_test_scaled = scaler.transform(x_test)\n\n# Logistic Regression modelini eğitme\nlog_reg = LogisticRegression(random_state=0)\nlog_reg.fit(x_train_scaled, y_train)\n\n# Tahmin yapma\ny_pred = log_reg.predict(x_test_scaled)\n\n# Confusion matrix oluşturma\ncm = confusion_matrix(y_test, y_pred)\nprint("Confusion Matrix:")\nprint(cm)\n\n# Metikleri hesaplama\nTP = cm[1, 1]  # True Positives\nTN = cm[0, 0]  # True Negatives\nFP = cm[0, 1]  # False Positives\nFN = cm[1, 0]  # False Negatives\n\n# Doğruluk\naccuracy = (TP + TN) / float(TP + TN + FP + FN)\nprint(f"Accuracy: {accuracy}")\n\n# Hassasiyet (Recall)\nsensitivity = TP / float(TP + FN)\nprint(f"Sensitivity (Recall): {sensitivity}")\n\n# Özgüllük (Specificity)\nspecificity = TN / float(TN + FP)\nprint(f"Specificity: {specificity}")\n\n# Kesinlik (Precision)\nprecision = TP / float(TP + FP)\nprint(f"Precision: {precision}")\n\n# F1 Skor\nf1 = f1_score(y_test, y_pred)\nprint(f"F1 Score: {f1}")\n\n# Alternatif olarak scikit-learn metriklerini kullanarak hesaplayabilirsiniz:\naccuracy = accuracy_score(y_test, y_pred)\nprecision = precision_score(y_test, y_pred)\nrecall = recall_score(y_test, y_pred)  # recall = sensitivity\nf1 = f1_score(y_test, y_pred)\n\nprint(f"Accuracy: {accuracy}")\nprint(f"Precision: {precision}")\nprint(f"Recall (Sensitivity): {recall}")\nprint(f"F1 Score: {f1}")\n\n'
